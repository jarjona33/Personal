# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# TypeError: read_sql_query() missing 1 required positional argument: 'con'

# %%
#This is just putting data from the internet into a pandas dataframe
df = pd.read_json("https://data.smcgov.org/resource/mb6a-xn89.json")

df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>geography</th>
#       <th>geography_type</th>
#       <th>year</th>
#       <th>less_than_high_school_graduate</th>
#       <th>high_school_graduate</th>
#       <th>some_college_or_associate_s_degree</th>
#       <th>bachelor_s_degree_or_higher</th>
#       <th>location_1</th>
#       <th>:@computed_region_uph5_8hpn</th>
#       <th>:@computed_region_i2t2_cryp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Atherton</td>
#       <td>Town</td>
#       <td>2014-01-01T00:00:00.000</td>
#       <td>13.6</td>
#       <td>12.3</td>
#       <td>2.7</td>
#       <td>3.5</td>
# ...

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>less_than_high_school_graduate</th>
#       <th>high_school_graduate</th>
#       <th>some_college_or_associate_s_degree</th>
#       <th>bachelor_s_degree_or_higher</th>
#       <th>:@computed_region_uph5_8hpn</th>
#       <th>:@computed_region_i2t2_cryp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>32.00000</td>
#       <td>32.000000</td>
#       <td>32.000000</td>
#       <td>32.000000</td>
#       <td>30.000000</td>
#       <td>32.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>17.80000</td>
#       <td>6.462500</td>
#       <td>5.946875</td>
# ...

# %%
df = pd.read_excel("Sample sale data")
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>OrderDate</th>
#       <th>Region</th>
#       <th>Rep</th>
#       <th>Item</th>
#       <th>Units</th>
#       <th>Unit Cost</th>
#       <th>Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2019-01-06</td>
#       <td>East</td>
#       <td>Jones</td>
#       <td>Pencil</td>
#       <td>95</td>
#       <td>1.99</td>
#       <td>189.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2019-01-23</td>
#       <td>Central</td>
#       <td>Kivell</td>
#       <td>Binder</td>
#       <td>50</td>
#       <td>19.99</td>
#       <td>999.50</td>
#     </tr>
#     <tr>
# ...

# %%
df = pd.read_excel("Sample sale data")

df.Total.mean()
# Out:
# 456.46232558139553

# %%
df = pd.read_excel("Sample sale data")

df.Units.mean()
# Out:
# 49.325581395348834

# %%
df = pd.read_excel("Sample sale data")

fig = px.bar(df, x="OrderDate", y="Units", color="Item")
fig.show()
# Out:
# Unsupported

# %%
df = pd.read_excel("Sample sale data")

fig = px.scatter(df, x="OrderDate", y="Total", color="Rep", size="Units")
fig.show()
# Out:
# Unsupported
